# %% [markdown]
# <a href="https://colab.research.google.com/github/simulate111/Automatic-text-processing-2025/blob/main/atp_2025_notebook_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##First commands
#
#
# Bash in Colab
# *   **always** use `!` before a command in Bash **in Notebook** (Colab)
# *   without `!` Notebook will interpret the command as Python
#
# Commenting out
# *   lines with `#` are comments
# *   they do not get executed
# *   a handy way to keep commands/code in the cell e.g., for future use!
# *   `#` can also be used to add comments to a code block, e.g., what the command does, or to give extra information
#
# Executing code blocks
# *   a code block can be executed by clicking the play-button on the upper left corner of the block, or by pressing `Ctrl + Enter` while in the block
# *   Colab will (probably) ask you to connect to Colab's server, just click ok
#
# Output
# *   the results of the code will be printed underneath the code block

# %% [markdown]
# **Let's start with printing**
# *   `echo` will print whatever you want

# %%
# This is what a command in Bash looks like
! echo Hello world in Bash!

# This is what a command in Python looks like
# (we will not learn Python in this course, though we will use some ready-made
# Python scripts later, this is just an example)
print("Hello world in Python!")
# Out:
# Hello world in Bash!
# Hello world in Python!

# %%
# This is what happens if you omit !
#echo Hello world
# !echo Hello world
# Out:
# Hello world

# %% [markdown]
# **Jumping right into it: How to download data**
# *   `wget` - get a file from a url
# *   Today, we'll get some mystery data from project Gutenberg at www.gutenberg.org
# *   select `Plain Text UTF-8` for downloading `.txt` files
# *   `.txt` in the end of the filename means it is a text file
# *   The command below will temporarily download the file into Colab's default folder and it will disappear when you close the notebook

# %%
# get the file
! wget https://www.gutenberg.org/cache/epub/20748/pg20748.txt
# Out:
# --2025-10-27 09:39:09--  https://www.gutenberg.org/cache/epub/20748/pg20748.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238904 (233K) [text/plain]
# Saving to: ‘pg20748.txt’
#
# pg20748.txt         100%[===================>] 233.30K  --.-KB/s    in 0.1s
#
# 2025-10-27 09:39:10 (1.92 MB/s) - ‘pg20748.txt’ saved [238904/238904]

# %% [markdown]
# **Check that the file exists**
# *   `ls` - list all files and folders in your current working directory
#     (we will learn how to access different directories aka folders later)

# %%
# see what you've got
! ls

# (do not worry about 'sample_data', it's Colab's default stuff and
# it's just always there)
# Out:
# pg20748.txt  sample_data

# %% [markdown]
# **Then let's have a look at the file**
# *   `cat` - concatenate aka **print** an entire file
# *   `head` - print the **first** lines of a file (default: 10 lines)
# *   `tail` - print the **last** lines of a file (default: 10 lines)

# %%
# print the entire file
! cat pg20748.txt

# NB! If you get ovewhelmed by the length of an output,
# click on the icon left to the output and choose
# "show/hide output"
# Out:
# ﻿The Project Gutenberg eBook of Favorite Fairy Tales
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Favorite Fairy Tales
#
# Editor: Logan Marshall
#
# Release date: March 5, 2007 [eBook #20748]
#                 Most recently updated: December 9, 2022
#
# Language: English
#
# Credits: Produced by Bruce Albrecht, Jacqueline Jeremy and the
#         Online Distributed Proofreading Team at https://www.pgdp.net
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK FAVORITE FAIRY TALES ***
#
#
#
#
# Produced by Bruce Albrecht, Jacqueline Jeremy and the
# ...

# %%
# only take a look at the beginning and end of the file
! head pg20748.txt
! echo "---------break-----------"
! tail pg20748.txt
# Out:
# ﻿The Project Gutenberg eBook of Favorite Fairy Tales
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# ---------break-----------
#
# Most people start at our website which has the main PG search
# facility: www.gutenberg.org.
#
# This website includes information about Project Gutenberg™,
# including how to make donations to the Project Gutenberg Literary
# Archive Foundation, how to help produce our new eBooks, and how to
# subscribe to our email newsletter to hear about new eBooks.

# %% [markdown]
# **Fine tuning your commands with flags**
#
# *   flags are tiny add-ons to commands that can modify how the command behaves
# *   they start with a `-` (a dash)
# *   each command has their own set of flags that do different things; there can be a lot of them and you don't have to learn them all (nobody does!), but we will use some useful ones in this course
#
#     **FOR EXAMPLE:**
#
#     you can define how many lines you want to show with head and tail by adding a number after the command but before the file name
#
#
#     `-1` (dash one) outputs only the first (`head -1`) or the last line (`tail -1`)
#
#     `-2` outputs two lines
#
#
# **N.B.**
# White spaces (often) matter in commands. So make sure that e.g., when using flags, there is no white space between the dash and the rest of the flag:
#
# `head -5 textfile.txt`

# %%
# example on how to show only the first and last line of the file
! head -1 pg20748.txt
! tail -1 pg20748.txt
# notice that the last line is empty!
# Out:
# ﻿The Project Gutenberg eBook of Favorite Fairy Tales

# %% [markdown]
# **Now try writing your own code!**
#
# The best way to learn is to write and try things yourself! So try to do the following steps by writing into the code cell below:
#
# 1.  **Download** the file from here: https://raw.githubusercontent.com/aristila/totally-random-stuff/refs/heads/main/bash_limerick.txt

# %%
# Download the file
! wget https://raw.githubusercontent.com/aristila/totally-random-stuff/refs/heads/main/bash_limerick.txt


# (EXTRA: you can try running this code cell a couple of times,
# then checking with 'ls' to see what you have)
# Out:
# --2025-10-27 09:39:11--  https://raw.githubusercontent.com/aristila/totally-random-stuff/refs/heads/main/bash_limerick.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 150 [text/plain]
# Saving to: ‘bash_limerick.txt’
#
# bash_limerick.txt   100%[===================>]     150  --.-KB/s    in 0s
#
# 2025-10-27 09:39:11 (3.03 MB/s) - ‘bash_limerick.txt’ saved [150/150]

# %% [markdown]
# 2. Print the **entire** file
# 3. Print only **the last three lines** of the file.

# %%
# Print the entire file
! cat bash_limerick.txt

! echo "-------------------------------------------------"
# Print only the last three lines of the file.
! tail -3 bash_limerick.txt
# Out:
# There once was a coder named Mash,
# Who set out to master some Bash.
# With "echo" and "grep,"
# He made quite a rep,
# Now scripts he can write in a flash!
# -------------------------------------------------
# With "echo" and "grep,"
# He made quite a rep,
# Now scripts he can write in a flash!

# %% [markdown]
# 4 (EXTRA). Try what happens if you use **echo** instead of cat to print the file

# %%
! echo bash_limerick.txt
# Out:
# bash_limerick.txt

# %% [markdown]
# **Finding help and instructions**
# *   Google is often helpful
# *   Inside Unix `man` (manuals), e.g. `man wget`

# %% [markdown]
# **More commands: file manipulation**
#
# `>` saves the output of the command to a file (by **overwriting** it if the file existed)
#
# `>>` **appends** the output of the command to the end of a file (no overwriting)
#
# `rm` removes the file (N.B. removes **without double-checking**)
#
# `cp` copies a file
#
# `mv` moves a file (or **renames**)
#
# `wc -w` is word count; `wc` can also be used to count lines (more about this later)

# %%
#! unminimize #required package for ! man -----  this required input "y"

# %%
#! man wget

# %%
# save head of the file to a new file
! head pg20748.txt > head.txt

! echo "--------------------------------------"
# check what you have
! ls

! echo "----------------------------------"
# print the new file
! cat head.txt
# Out:
# --------------------------------------
# bash_limerick.txt  head.txt  pg20748.txt  sample_data
# ----------------------------------
# ﻿The Project Gutenberg eBook of Favorite Fairy Tales
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.

# %%
# count the words in the new file
! wc -w head.txt
# Out:
# 90 head.txt

# %%
# remove the new file
! rm head.txt

! echo "--------------------------------------"
# check what you have
! ls
# Out:
# --------------------------------------
# bash_limerick.txt  pg20748.txt	sample_data

# %%
# save tail to a new file
! tail pg20748.txt > tail.txt

! echo "--------------------------------------"
# copy the tail to a new file (cf. save as)
! cp tail.txt copyoftail.txt

! echo "--------------------------------------"
# try copying the head.txt file
! cp head.txt copyofhead.txt

! echo "--------------------------------------"
! ls
# Out:
# --------------------------------------
# --------------------------------------
# cp: cannot stat 'head.txt': No such file or directory
# --------------------------------------
# bash_limerick.txt  copyoftail.txt  pg20748.txt	sample_data  tail.txt

# %%
# rename a file (mv also can move files between folders - we'll learn to do this later)
! mv copyoftail.txt somethingelse.txt # so moving moves / renames, copying leaves the original

! echo "--------------------------------------"
! ls
# Out:
# --------------------------------------
# bash_limerick.txt  pg20748.txt	sample_data  somethingelse.txt	tail.txt

# %% [markdown]
# **Exercises**
# 1.   Choose another **book from Gutenberg** and **download** it
# 1.   Make a **backup copy** of the file and **delete** the original
# 1.   Then **move (rename)** the backup file as something else
# 1.   **Check** with **`ls`** that all is how you intended
# 2.   **Save** the head and tail outputs of the new book **into separate files**
# 2.   **Check** with **`cat`** that you got what you wanted
# 2.   Then try to use **`wc -w`**. How many words did **the original book** have?
# 2.   How many words did **head and tail outputs** have?
# 1.   How would you **print the output of `wc -w` to a file**?

# %%
#1
! wget https://www.gutenberg.org/cache/epub/77131/pg77131.txt

! echo "--------------------------------------"
# !ls
# Out:
# --2025-10-27 09:39:13--  https://www.gutenberg.org/cache/epub/77131/pg77131.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116998 (114K) [text/plain]
# Saving to: ‘pg77131.txt’
#
# pg77131.txt         100%[===================>] 114.26K  --.-KB/s    in 0.08s
#
# 2025-10-27 09:39:14 (1.45 MB/s) - ‘pg77131.txt’ saved [116998/116998]
#
# --------------------------------------
# bash_limerick.txt  pg77131.txt	somethingelse.txt
# pg20748.txt	   sample_data	tail.txt

# %%
#2
! cp pg77131.txt backup.txt
! echo "--------------------------------------"
# !ls
! echo "--------------------------------------"
! rm pg77131.txt
# !echo "--------------------------------------"
# !ls
# Out:
# --------------------------------------
# backup.txt	   pg20748.txt	sample_data	   tail.txt
# bash_limerick.txt  pg77131.txt	somethingelse.txt
# --------------------------------------
# --------------------------------------
# backup.txt	   pg20748.txt	somethingelse.txt
# bash_limerick.txt  sample_data	tail.txt

# %%
#3
! mv backup.txt somethingelse.txt
# !echo "--------------------------------------"
# !ls
# Out:
# --------------------------------------
# bash_limerick.txt  pg20748.txt	sample_data  somethingelse.txt	tail.txt

# %%
#4
# !ls
# Out:
# bash_limerick.txt  pg20748.txt	sample_data  somethingelse.txt	tail.txt

# %%
#5
! head somethingelse.txt > headofsomethingelse.txt
! tail somethingelse.txt > tailofsomethingelse.txt
# !echo "--------------------------------------"
# !ls
# Out:
# --------------------------------------
# bash_limerick.txt	 pg20748.txt  somethingelse.txt        tail.txt
# headofsomethingelse.txt  sample_data  tailofsomethingelse.txt

# %%
#6
# !cat headofsomethingelse.txt
# !echo "--------------------------------------"
# !cat tailofsomethingelse.txt
# Out:
# ﻿The Project Gutenberg eBook of Drug themes in science fiction
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# --------------------------------------
#
# Most people start at our website which has the main PG search
# facility: www.gutenberg.org.
#
# This website includes information about Project Gutenberg™,
# including how to make donations to the Project Gutenberg Literary
# Archive Foundation, how to help produce our new eBooks, and how to
# subscribe to our email newsletter to hear about new eBooks.

# %%
#7
! wc -w somethingelse.txt
# Out:
# 15444 somethingelse.txt

# %%
#8
! wc -w headofsomethingelse.txt
! echo "--------------------------------------"
! wc -w tailofsomethingelse.txt
# Out:
# 92 headofsomethingelse.txt
# --------------------------------------
# 53 tailofsomethingelse.txt

# %%
#9 or
! wc -w headofsomethingelse.txt tailofsomethingelse.txt #somethingelse.txt
# Out:
#  92 headofsomethingelse.txt
#  53 tailofsomethingelse.txt
# 145 total

# %%
#9
! wc -w somethingelse.txt > WCsomethingelse.txt
! echo "--------------------------------------"
# !ls
! echo "--------------------------------------"
# !cat WCsomethingelse.txt
# Out:
# --------------------------------------
# bash_limerick.txt	 sample_data		  tail.txt
# headofsomethingelse.txt  somethingelse.txt	  WCsomethingelse.txt
# pg20748.txt		 tailofsomethingelse.txt
# --------------------------------------
# 15444 somethingelse.txt

# %%
#9 or
! wc -w headofsomethingelse.txt tailofsomethingelse.txt somethingelse.txt > WCsomethingelseAll.txt
# !ls
# Out:
# bash_limerick.txt	 sample_data		  tail.txt
# headofsomethingelse.txt  somethingelse.txt	  WCsomethingelseAll.txt
# pg20748.txt		 tailofsomethingelse.txt  WCsomethingelse.txt

# %%
! cat WCsomethingelseAll.txt
# Out:
#     92 headofsomethingelse.txt
#     53 tailofsomethingelse.txt
#  15444 somethingelse.txt
#  15589 total

# %%
## For super fast students

#Remov the first details of a text

! cat somethingelse.txt
# Out:
# ﻿The Project Gutenberg eBook of Drug themes in science fiction
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Drug themes in science fiction
#
# Author: Robert Silverberg
#
# Author of introduction, etc.: Dan J. Lettieri
#
# Illustrator: William Blake
#
# Release date: October 26, 2025 [eBook #77131]
#
# Language: English
#
# Original publication: Rockville, MD: National Institute on Drug Abuse, 1974
#
# ...

# %%
# find the introduction parts manuaaly by modifying head command
# !head -117 somethingelse.txt
# Out:
# ﻿The Project Gutenberg eBook of Drug themes in science fiction
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Drug themes in science fiction
#
# Author: Robert Silverberg
#
# Author of introduction, etc.: Dan J. Lettieri
#
# Illustrator: William Blake
#
# Release date: October 26, 2025 [eBook #77131]
#
# Language: English
#
# Original publication: Rockville, MD: National Institute on Drug Abuse, 1974
#
# ...

# %%
# total document lines with ! wc -l  --------
! wc -l somethingelse.txt
! echo "-----------------------"
! wc somethingelse.txt
# Out:
# 3228 somethingelse.txt
# -----------------------
#   3228  15444 116998 somethingelse.txt

# %%
#remove intriduction head part from the main text, removing 117 lines from the total lines 3228-117=3111 lines of tails

! tail -3111 somethingelse.txt
# Out:
#                                 FOREWORD
#
#
#     The issues of drug use and abuse have generated many volumes of
# words, all written in an attempt to explain the “problem” and suggest
# the “solution.” Data have been generated by researchers from many
# disciplines, each looking at a particular aspect of an issue. The
# present booklet is one of a new series intended to aid researchers who
# find it difficult to find the time to scan, let alone read all the
# information which exists and which continues to be published daily in
# their area of interest. An attempt has been made to focus predominantly
# on empirical research findings and major theoretical approaches.
#
#     Included in volumes 1 through 7 of the series are summaries of the
# major research findings of the last 15 years, formulated and detailed
# to provide the reader with the purpose, methodology, findings and
# conclusions of previous studies done in the topic area. Each topic was
# ...

# %% [markdown]
# ##What did we learn today?
#
# *   print text in Bash
# *   download data
# *   check the contents of a folder (directory)
# *   print files and their beginnings and ends
# *   save and append text to a file
# *   copy, move and remove files
# *   count words in a file
